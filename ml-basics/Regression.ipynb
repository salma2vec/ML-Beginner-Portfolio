# %% [markdown]
# <a href="https://colab.research.google.com/github/IdealisticINTJ/ubiquitous-broccoli/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %%
# Necessary imports
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Creating the dataset
N = 1000
X = np.random.random((N, 2)) * 6 - 3 
Y = np.cos(2*X[:,0]) + np.cos(3*X[:,1])

# %%
# Plotting it
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)
# plt.show()

# %%
# Building the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, input_shape=(2,), activation='relu'),
  tf.keras.layers.Dense(1)
])

# %%
# Compiling and fitting
opt = tf.keras.optimizers.Adam(0.01)
model.compile(optimizer=opt, loss='mse')
r = model.fit(X, Y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 0s 968us/step - loss: 1.0215
# Epoch 2/100
# 32/32 [==============================] - 0s 945us/step - loss: 0.9292
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8181
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8697
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8538
# Epoch 6/100
# 32/32 [==============================] - 0s 920us/step - loss: 0.8476
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7894
# Epoch 8/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7564
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6595
# Epoch 10/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6518
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6768
# Epoch 12/100
# ...

# %%
# Plotting the loss
plt.plot(r.history['loss'], label='loss')

# %%
# Plotting the prediction surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# A surface plot
line = np.linspace(-3, 3, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()

# %%
# Plotting the prediction surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# A surface plot
line = np.linspace(-5, 5, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()
