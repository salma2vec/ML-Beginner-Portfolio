0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0393-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0395-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0396-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0406-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0419-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0437-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0448-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0455-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0463-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0465-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0473-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0481-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0500-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0508-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0512-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0513-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0515-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0520-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0537-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0539-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0541-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0554-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0555-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0568-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0572-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0587-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0587-0001-0002.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0596-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0611-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0618-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0626-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0645-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0651-0004.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0653-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0675-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0680-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0693-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0695-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0808-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0812-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0830-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0832-0001-0002.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0843-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0858-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0869-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0874-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0879-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0887-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0909-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0912-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0927-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0937-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0951-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0952-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0955-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0961-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0962-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0994-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0995-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-0995-0001-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1002-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1004-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1028-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1039-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1053-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1058-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1088-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1091-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1103-0001-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1109-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1117-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1126-0001.jpeg
#   inflating: Covid_Dataset/Train/Normal/NORMAL2-IM-1136-0001.jpeg
# Data set successfully imported.

# %%
path = "./Covid_Dataset/"
filepath = []

for root, directories, files in os.walk(path, topdown=False):
  for name in files:
    filepath.append(os.path.join(root, name))


set = []
diagnosis = []
imgname = []

for i in filepath:
  imgname.append(i.split("/")[4])
  set.append(i.split("/")[2])
  diagnosis.append(i.split("/")[3])

df = pd.DataFrame(list(zip(imgname, set, diagnosis)),
                  columns = ['Filename', 'Set', 'Diagnosis'])

df.to_csv('covid_metadata.csv', index=False)

df.sample(5)
# Out:
#                       Filename    Set Diagnosis
# 226  all14238-fig-0001-m-b.jpg  Train     Covid
# 113  NORMAL2-IM-0843-0001.jpeg  Train    Normal
# 0    NORMAL2-IM-1338-0001.jpeg   Test    Normal
# 315               441c9cdd.jpg  Train     Covid
# 176  NORMAL2-IM-0955-0001.jpeg  Train    Normal

# %%
sns.countplot(data=df, x='Set')
plt.title('Count of Train/Test Samples');

# %%
normal_images_train = list(paths.list_images(f"./Covid_Dataset/Train/Normal/"))
covid_images_train = list(paths.list_images(f"./Covid_Dataset/Train/Covid/"))

def plots_from_files(imspaths, figsize=(18,9), display_images=25, rows=1, cols=1, titles=None, maintitle=None):
    f = plt.figure(figsize=figsize)
    if maintitle is not None: plt.suptitle(maintitle, fontsize=40)
    
    for i in range(0, display_images):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=16)
        img = plt.imread(imspaths[i])
        plt.imshow(img)

# %%
plots_from_files(normal_images_train, rows=5, cols=5, display_images=25, maintitle="Normal X-Ray Images")

# %%
plots_from_files(covid_images_train, rows=5, cols=5, display_images=25, maintitle="Covid-19 Infected Lungs X-Ray Images")

# %%
# Building a CNN Based Model in Keras.
model = Sequential()

model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(224,224,3)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss=keras.losses.binary_crossentropy, optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 64)      18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 110, 110, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                5537856
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,668,097
# Trainable params: 5,668,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 33
BS = 32

# %%
train_data = image.ImageDataGenerator(
    rescale = 1./255, 
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True
)

# %%
test_data = image.ImageDataGenerator(rescale = 1./255)

# %%
train_generator = train_data.flow_from_directory(
    'Covid_Dataset/Train',
    target_size = (224,224),
    batch_size = BS,
    class_mode = 'binary'
)
# Out:
# Found 288 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'Covid': 0, 'Normal': 1}

# %%
test_generator = test_data.flow_from_directory(
    'Covid_Dataset/Test',
    target_size = (224,224),
    batch_size = BS,
    class_mode = 'binary'
)
# Out:
# Found 72 images belonging to 2 classes.

# %%
# %%time

hist = model.fit_generator(
    train_generator,
    
    steps_per_epoch = 8,
    epochs = EPOCHS,
    validation_data = test_generator,
    validation_steps = 2
    
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/33
# 8/8 [==============================] - 103s 11s/step - loss: 2.2128 - accuracy: 0.4604 - val_loss: 0.6886 - val_accuracy: 0.5156
# Epoch 2/33
# 8/8 [==============================] - 83s 10s/step - loss: 0.6331 - accuracy: 0.6695 - val_loss: 0.5152 - val_accuracy: 0.9375
# Epoch 3/33
# 8/8 [==============================] - 93s 12s/step - loss: 0.4799 - accuracy: 0.7684 - val_loss: 0.3859 - val_accuracy: 0.9375
# Epoch 4/33
# 8/8 [==============================] - 85s 11s/step - loss: 0.3018 - accuracy: 0.8637 - val_loss: 0.3033 - val_accuracy: 0.9375
# Epoch 5/33
# 8/8 [==============================] - 85s 11s/step - loss: 0.3785 - accuracy: 0.8686 - val_loss: 0.1791 - val_accuracy: 0.9375
# Epoch 6/33
# 8/8 [==============================] - 84s 10s/step - loss: 0.1980 - accuracy: 0.9294 - val_loss: 0.3130 - val_accuracy: 0.9531
# Epoch 7/33
# 8/8 [==============================] - 85s 11s/step - loss: 0.2247 - accuracy: 0.9392 - val_loss: 0.2071 - val_accuracy: 0.9531
# Epoch 8/33
# 8/8 [==============================] - 84s 10s/step - loss: 0.2471 - accuracy: 0.9213 - val_loss: 0.1864 - val_accuracy: 0.9531
# Epoch 9/33
# 8/8 [==============================] - 87s 11s/step - loss: 0.1874 - accuracy: 0.9585 - val_loss: 0.2213 - val_accuracy: 0.9844
# Epoch 10/33
# 8/8 [==============================] - 84s 10s/step - loss: 0.2511 - accuracy: 0.9307 - val_loss: 0.0983 - val_accuracy: 0.9844
# Epoch 11/33
# 8/8 [==============================] - 84s 10s/step - loss: 0.1905 - accuracy: 0.9399 - val_loss: 0.0832 - val_accuracy: 0.9844
# Epoch 12/33
# 8/8 [==============================] - 83s 10s/step - loss: 0.2581 - accuracy: 0.9000 - val_loss: 0.1582 - val_accuracy: 0.9531
# Epoch 13/33
# 8/8 [==============================] - 83s 10s/step - loss: 0.1617 - accuracy: 0.9431 - val_loss: 0.1860 - val_accuracy: 0.9531
# Epoch 14/33
# 8/8 [==============================] - 84s 10s/step - loss: 0.2494 - accuracy: 0.9148 - val_loss: 0.1970 - val_accuracy: 0.9531
# Epoch 15/33
# 8/8 [==============================] - 84s 11s/step - loss: 0.2622 - accuracy: 0.8567 - val_loss: 0.1793 - val_accuracy: 0.9531
# Epoch 16/33
# 8/8 [==============================] - 93s 12s/step - loss: 0.2890 - accuracy: 0.8335 - val_loss: 0.2801 - val_accuracy: 0.9688
# Epoch 17/33
# 8/8 [==============================] - 84s 10s/step - loss: 0.2567 - accuracy: 0.8845 - val_loss: 0.1905 - val_accuracy: 0.9688
# Epoch 18/33
# 8/8 [==============================] - 83s 10s/step - loss: 0.3748 - accuracy: 0.8759 - val_loss: 0.1549 - val_accuracy: 0.9688
# Epoch 19/33
# 8/8 [==============================] - 82s 10s/step - loss: 0.2040 - accuracy: 0.9289 - val_loss: 0.1490 - val_accuracy: 0.9531
# Epoch 20/33
# 8/8 [==============================] - 83s 10s/step - loss: 0.2597 - accuracy: 0.8862 - val_loss: 0.2411 - val_accuracy: 0.9531
# Epoch 21/33
# 8/8 [==============================] - 83s 10s/step - loss: 0.2137 - accuracy: 0.8817 - val_loss: 0.1353 - val_accuracy: 0.9531
# Epoch 22/33
# 8/8 [==============================] - 84s 10s/step - loss: 0.2165 - accuracy: 0.8938 - val_loss: 0.1375 - val_accuracy: 0.9688
# Epoch 23/33
# 8/8 [==============================] - 85s 11s/step - loss: 0.1777 - accuracy: 0.9448 - val_loss: 0.1055 - val_accuracy: 0.9531
# Epoch 24/33
# 8/8 [==============================] - 83s 10s/step - loss: 0.1676 - accuracy: 0.9447 - val_loss: 0.0958 - val_accuracy: 0.9688
# Epoch 25/33
# 8/8 [==============================] - 83s 10s/step - loss: 0.3395 - accuracy: 0.8826 - val_loss: 0.1569 - val_accuracy: 0.9688
# Epoch 26/33
# 8/8 [==============================] - 82s 10s/step - loss: 0.2872 - accuracy: 0.9305 - val_loss: 0.1410 - val_accuracy: 0.9531
# Epoch 27/33
# 8/8 [==============================] - 83s 10s/step - loss: 0.3139 - accuracy: 0.8610 - val_loss: 0.1300 - val_accuracy: 0.9688
# Epoch 28/33
# 8/8 [==============================] - 84s 10s/step - loss: 0.1608 - accuracy: 0.9443 - val_loss: 0.1072 - val_accuracy: 0.9531
# Epoch 29/33
# 8/8 [==============================] - 84s 10s/step - loss: 0.1883 - accuracy: 0.9562 - val_loss: 0.1060 - val_accuracy: 0.9688
# Epoch 30/33
# 8/8 [==============================] - 83s 10s/step - loss: 0.1850 - accuracy: 0.9435 - val_loss: 0.1206 - val_accuracy: 0.9688
# Epoch 31/33
# 8/8 [==============================] - 83s 10s/step - loss: 0.2042 - accuracy: 0.9461 - val_loss: 0.0997 - val_accuracy: 0.9688
# Epoch 32/33
# 8/8 [==============================] - 82s 10s/step - loss: 0.2233 - accuracy: 0.9466 - val_loss: 0.0907 - val_accuracy: 0.9688
# Epoch 33/33
# 8/8 [==============================] - 82s 10s/step - loss: 0.1949 - accuracy: 0.9338 - val_loss: 0.0436 - val_accuracy: 0.9844
# CPU times: user 1h 27min 3s, sys: 1min 16s, total: 1h 28min 19s
# Wall time: 1h 3min 8s

# %%
# checkpoint to save highest accuracy
"""
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
"""
# Out:
# '\nfilepath="weights.best.hdf5"\ncheckpoint = ModelCheckpoint(filepath, monitor=\'val_accuracy\', verbose=1, save_best_only=True, mode=\'max\')\ncallbacks_list = [checkpoint]\n'

# %%
if os.path.exists("covid19_model_adv.h5"):
   os.remove("covid19_model_adv.h5")
   print("Previous model deleted.")
else :
   print("The file does not exist.")

model.save("covid19_model_adv.h5")
print("Most recent model saved as: covid19_model_adv.h5")
# Out:
# The file does not exist.
# Most recent model saved as: covid19_model_adv.h5

# %%
model.save_weights("covid19_model_weights.h5")
print("Model weights saved.")

# save to JSON format
model_json = model.to_json()
with open('covid19_model_adv.json', 'w') as json_file:
  json_file.write(model_json)

print('Model saved to JSON format.')
# Out:
# Model weights saved.
# Model saved to JSON format.

# %%
model = load_model("covid19_model_adv.h5")
print('Model loaded from file.')
# Out:
# Model loaded from file.

# %%
train_generator.class_indices
# Out:
# {'Covid': 0, 'Normal': 1}

# %%
y_actual = []
y_test = []

# %%
for i in os.listdir("./Covid_Dataset/Test/Normal/"):
  img = image.load_img("./Covid_Dataset/Test/Normal/" + i, target_size=(224,224))
  img = image.img_to_array(img)
  img = np.expand_dims(img, axis=0)
  p = model.predict_classes(img)
  y_test.append(p[0,0])
  y_actual.append(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
for i in os.listdir("./Covid_Dataset/Test/Covid/"):
  img = image.load_img("./Covid_Dataset/Test/Covid/" + i, target_size=(224,224))
  img = image.img_to_array(img)
  img = np.expand_dims(img, axis=0)
  p = model.predict_classes(img)
  y_test.append(p[0,0])
  y_actual.append(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
y_actual = np.array(y_actual)
y_test = np.array(y_test)

# %%
model.evaluate_generator(train_generator)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1948: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# [0.10479879379272461, 0.9618055820465088]

# %%
model.evaluate_generator(test_generator)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1948: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# [0.040936049073934555, 0.9861111044883728]

# %%
cm = confusion_matrix(y_actual, y_test)
target_names = {'Covid': 0, 'Normal': 1}

ax = plt.axes()
sns.heatmap(cm, 
            cmap="inferno", 
            annot=True, 
            fmt='g', 
            yticklabels=target_names, 
            xticklabels=target_names)
ax.set_title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test, y_actual, target_names=target_names))
print("Precision score: {:.4f}".format(precision_score(y_actual, y_test)))
print("Recall score: {:.4f}".format(recall_score(y_actual, y_test)))
print("F1 Score: {:.4f}".format(f1_score(y_actual, y_test)))
# Out:
#               precision    recall  f1-score   support
#
#        Covid       0.97      0.95      0.96        37
#       Normal       0.94      0.97      0.96        35
#
#     accuracy                           0.96        72
#    macro avg       0.96      0.96      0.96        72
# weighted avg       0.96      0.96      0.96        72
#
# Precision score: 0.9714
# Recall score: 0.9444
# F1 Score: 0.9577

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.figure(figsize=(15,5))
plt.plot(np.arange(0, N), hist.history["loss"], label="train_loss", color='blue', linestyle=':')
plt.plot(np.arange(0, N), hist.history["val_loss"], label="val_loss", color='red', linestyle=':')
plt.plot(np.arange(0, N), hist.history["accuracy"], label="train_acc", color='blue')
plt.plot(np.arange(0, N), hist.history["val_accuracy"], label="val_acc", color='red')
plt.title("Training/Validation Loss and Accuracy on the COVID-19 Dataset", fontsize=18)
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),prop={'size':10})
plt.show()

# %%
model = load_model("covid19_model_adv.h5")
random_image = random.choice(os.listdir("./Covid_Dataset/Test/Covid/"))
img = image.load_img("./Covid_Dataset/Test/Covid/" + random_image, target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
p = model.predict_classes(x)
print(random_image, p)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# covid-19-pneumonia-20.jpg [[0]]

# %% [markdown]
# **Conclusion**
#
# The accuracy obtained was approximately 96%.
